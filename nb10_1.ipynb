# %%
import my_math

# %%
my_math.add(2,3)
# Out:
# 5

# %%
import my_math as mm
mm.add(2,3)
# Out:
# 5

# %%
from my_math import add
add(3,6)
# Out:
# 9

# %%
from my_math import add as a
a(3,6)
# Out:
# 9

# %%
# great package
# great/ko.py-ko_great(), en.py-en_great()

# %%
import great
great.ko.ko_greet("홍길동")
# Out:
# '안녕하세요, 홍길동!'

# %%
from great import *
ko.ko_greet("홍길동")
# Out:
# '안녕하세요, 홍길동!'

# %%
import great
great.ko.ko_greet("Park")
# Out:
# '안녕하세요, Park!'
