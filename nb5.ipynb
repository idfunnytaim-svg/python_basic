# %%
# 64bit=8byte
# 한글같은 경우 한글자당1byte
# 정수 범위 -128~0~127 =>256개의 int
# 파이썬은 정수크기가 정해지지않는다. 필요에 따라서 계속 커질수 있다.
# 파이썬은 숫자등등을 객체로 저장한다.
# 127에서 +1을 하면 -128 오버플로우가 된다.

# %%
n = 10
print(n.bit_length()) # 10의 이진수 값(1010)의 길이

# bin()함수는 인자로 입력된 10진수의 2진수 문자열을 반환한다.
# 이진수 문자열 앞에 binary를 뜻하는 "0b"접두사를 앞에 붙여서 반환한다.
print(bin(n)) #0b1010 "0b" + "1010"

# bit_length()메서드는 n이라는 숫자 객체를 만들어야 존재하는 것이고,
# bin() 함수는 n객체와 상관없는 독립된 함수 객체이다.

print(bin(9)) # n과 상관없이 독립적으로 사용가능
# Out:
# 4
# 0b1010
# 0b1001

# %%
n2=(3,5)
print(n2[0])
# Out:
# 3

# %%
n2[0]=999
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 n2[0]=999
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 뒤에서 4개 중 2칸씩
nums = [10, 20, 30, 40, 50, 60, 70, 80]
print(nums[-4::2])
# Out:
# [50, 70]

# %%
# pop() : 인덱스로 삭제 후 반환
nums = [10, 20, 30]
result = nums.pop() # 마지막 인덱스 삭제 후 반환
print(result)
print(nums)
# Out:
# 30
# [10, 20]

# %%
# 정렬 메서드
nums = [50, 10, 40, 20]
nums.sort() # 오름차순
print(nums)

nums = [50, 10, 40, 20]
nums.sort(reverse=True) # 내림차순
print(nums)
# Out:
# [10, 20, 40, 50]
# [50, 40, 20, 10]

# %%
#set
a={1,2,3,2}
print(a)#set셋은 중복을 허용하지 않도록 설계
#리스트(list): 처음에 있는 데이터부터 끝까지 하나씩 다 열어봅니다. 
# 데이터가 100만 개 있으면 최악의 경우 100만 번을 확인해야 합니다. (느림)
#세트(set): '해시 테이블(Hash Table)'이라는 특별한 상자에 데이터를 저장합니다. 
# 데이터의 이름표를 보면 그 데이터가 어디 있는지 바로 알 수 있어서, 
# 데이터가 100만 개든 1억 개든 단 한 번에 찾아냅니다. (엄청나게 빠름)
# Out:
# {1, 2, 3}

# %%
print(a[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(a[0])
#
# TypeError: 'set' object is not subscriptable

# %%
print(list(a)[0])#셋은 인덱싱이 안된다.
#list로 만들어서 인덱싱한다.
#셋은 중복때문에 잘쓴다.
# Out:
# 1

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
a=[]
b={}
c=set()#셋은 이런식으로 해야지 빈 통으로 만들 수 있다.
print(type(a),type(b),type(c))
# Out:
# <class 'list'> <class 'dict'> <class 'set'>
